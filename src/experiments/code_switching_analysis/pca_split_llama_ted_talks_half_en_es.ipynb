# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

from core.utils.device import DEVICE
from core.utils.theme import set_theme

set_theme()

model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-3.2-1B")
model.to(DEVICE)
model.eval()
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-1B")

# %%
from core.gather_data.hidden_space import collect_hidden_space_by_language
from core.preprocess_data.flores_plus import load_flores_plus
from core.steering.pca import PCASteering

train_df, test_df = load_flores_plus(["eng_Latn", "spa_Latn"], {"eng_Latn": "en", "spa_Latn": "es"}, train_size=200)

hidden_space_by_language_train, token_map_for_language_train = collect_hidden_space_by_language(
    model, tokenizer, train_df, skip_first=True, cache_path="../../../.cache/hidden_space/llama_en_es_flores_train.pt"
)

pca_steering = PCASteering(cache_path="../../../.cache/pca/llama_en_es_flores.pt").fit(hidden_space_by_language_train)
# Out:
# Data len:  200
#   0%|          | 0/200 [00:00<?, ?it/s]
# 100%|██████████| 200/200 [04:21<00:00,  1.31s/it]
# /src/language-steering-in-latent-space/src/core/steering/pca.py:67: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   self.pca_components = torch.tensor(pca_components)

# %%
model.model.layers
# Out:
# ModuleList(
#   (0-15): 16 x LlamaDecoderLayer(
#     (self_attn): LlamaAttention(
#       (q_proj): Linear(in_features=2048, out_features=2048, bias=False)
#       (k_proj): Linear(in_features=2048, out_features=512, bias=False)
#       (v_proj): Linear(in_features=2048, out_features=512, bias=False)
#       (o_proj): Linear(in_features=2048, out_features=2048, bias=False)
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=2048, out_features=8192, bias=False)
#       (up_proj): Linear(in_features=2048, out_features=8192, bias=False)
#       (down_proj): Linear(in_features=8192, out_features=2048, bias=False)
#       (act_fn): SiLU()
#     )
#     (input_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#     (post_attention_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#   )
# )

# %%
from core.integration.SteeredLlamaDecoderLayer import SteeredLlamaDecoderLayer

replacement_layers: list[SteeredLlamaDecoderLayer] = []
for index in [14, 15]:
    replacement_layer = SteeredLlamaDecoderLayer(model.config, index, pca_steering, maintain_direction=False).to(
        model.device
    )
    original_layer = model.model.layers[index]
    replacement_layer.load_state_dict(original_layer.state_dict())
    model.model.layers[index] = replacement_layer
    replacement_layers.append(replacement_layer)

# %%
import json

import pandas as pd

# Load the code-switching data
data_path = "../../../data/ted_talks_code_switching_second_half.jsonl"
code_switching_data = []

with open(data_path, "r", encoding="utf-8") as f:
    for line in f:
        code_switching_data.append(json.loads(line))

# Convert to DataFrame for easier manipulation
df = pd.DataFrame(code_switching_data)

# Extract only eng_Latn and spa_Latn columns
df_en_ru = df[["eng_Latn", "spa_Latn"]].copy()

print(f"Loaded {len(df_en_ru)} samples")
print("\nFirst few examples:")
print(df_en_ru.head())
# Out:
# Loaded 2467 samples
#
# First few examples:
#                                             eng_Latn  \
# 0  Good morning. How are you?(Laughter)It's been ...
# 1  Thank you so much, Chris. And it's truly a gre...
# 2  (Music: "The Sound of Silence," Simon & Garfun...
# 3  If you're here today — and I'm very happy that...
# 4  About 10 years ago, I took on the task to teac...
#
#                                             spa_Latn
# 0  Good morning. How are you?(Laughter)It's been ...
# 1  Thank you so much, Chris. And it's truly a gre...
# 2  (Music: "The Sound of Silence," Simon & Garfun...
# 3  If you're here today — and I'm very happy that...
# 4  About 10 years ago, I took on the task to ense...

# %%
import numpy as np
import torch
from torch.nn import functional as F


def get_next_token_logits(model, tokenizer, text):
    """
    Get logits for next token prediction given input text.

    Args:
        model: The language model
        tokenizer: The tokenizer
        text: Input text string

    Returns:
        logits: Tensor of shape (vocab_size,) with logits for next token
    """
    # Tokenize the input
    inputs = tokenizer(text, return_tensors="pt").to(model.device)

    # Get model output
    with torch.no_grad():
        outputs = model(**inputs)

    # Get logits for the last token (next token prediction)
    logits = outputs.logits[0, -1, :]  # Shape: (vocab_size,)

    return logits


def compare_logit_distributions(sample_idx=0, top_k=20, verbose=True, steering_value=-3.0):
    """
    Compare logit distributions for a single sample across three conditions:
    1. eng_Latn text with steering disabled (baseline English)
    2. spa_Latn text with steering disabled (baseline Spanish)
    3. spa_Latn text with steering enabled (es->eng steering)

    Args:
        sample_idx: Index of the sample to analyze
        top_k: Number of top tokens to display
        verbose: Whether to print sample details and predictions
        steering_value: Steering direction value to apply (default: -3.0)

    Returns:
        Dictionary with logits and probabilities for all three conditions
    """
    # Get the text samples
    eng_text = df_en_ru.iloc[sample_idx]["eng_Latn"]
    es_text = df_en_ru.iloc[sample_idx]["spa_Latn"]

    if verbose:
        print(f"\n{'=' * 80}")
        print(f"Sample {sample_idx}")
        print(f"{'=' * 80}")
        print(f"\nEnglish text: {eng_text}")
        print(f"\nSpanish text: {es_text}")
        print(f"\n{'-' * 80}")

    # Condition 1: eng_Latn with steering disabled
    replacement_layers[0].disable()
    replacement_layers[1].disable()
    logits_eng_no_steer = get_next_token_logits(model, tokenizer, eng_text)
    probs_eng_no_steer = F.softmax(logits_eng_no_steer, dim=-1)

    # Condition 2: spa_Latn with steering disabled (baseline)
    replacement_layers[0].disable()
    replacement_layers[1].disable()
    logits_es_no_steer = get_next_token_logits(model, tokenizer, es_text)
    probs_es_no_steer = F.softmax(logits_es_no_steer, dim=-1)

    # Condition 3: spa_Latn with steering enabled (es->eng)
    replacement_layers[1].set_steering_direction(steering_value)
    logits_es_with_steer = get_next_token_logits(model, tokenizer, es_text)
    probs_es_with_steer = F.softmax(logits_es_with_steer, dim=-1)

    # Disable steering after we're done
    replacement_layers[0].disable()
    replacement_layers[1].disable()

    # Get top-k tokens for each condition
    top_k_eng = torch.topk(probs_eng_no_steer, top_k)
    top_k_es_no = torch.topk(probs_es_no_steer, top_k)
    top_k_es_yes = torch.topk(probs_es_with_steer, top_k)

    if verbose:
        print(f"\nTop-{top_k} predicted tokens:")
        print("\n1. English text (no steering - baseline):")
        for i, (prob, idx) in enumerate(zip(top_k_eng.values, top_k_eng.indices)):
            token = tokenizer.decode([idx])
            print(f"  {i + 1:2d}. {token:50s} (prob: {prob:.4f})")

        print("\n2. Spanish text (no steering - baseline):")
        for i, (prob, idx) in enumerate(zip(top_k_es_no.values, top_k_es_no.indices)):
            token = tokenizer.decode([idx])
            print(f"  {i + 1:2d}. {token:50s} (prob: {prob:.4f})")

        print("\n3. Spanish text (WITH steering es->eng):")
        for i, (prob, idx) in enumerate(zip(top_k_es_yes.values, top_k_es_yes.indices)):
            token = tokenizer.decode([idx])
            print(f"  {i + 1:2d}. {token:50s} (prob: {prob:.4f})")

    return {
        "eng_text": eng_text,
        "es_text": es_text,
        "logits_eng_no_steer": logits_eng_no_steer,
        "logits_es_no_steer": logits_es_no_steer,
        "logits_es_with_steer": logits_es_with_steer,
        "probs_eng_no_steer": probs_eng_no_steer,
        "probs_es_no_steer": probs_es_no_steer,
        "probs_es_with_steer": probs_es_with_steer,
    }


# Test with first sample
results = compare_logit_distributions(sample_idx=0, top_k=20)
# Out:
# ================================================================================
# Sample 0
# ================================================================================
#
# English text: Good morning. How are you?(Laughter)It's been great, hasn't it? I've been blown away by the whole thing. In fact, I'm
#
# Spanish text: Good morning. How are you?(Laughter)It's been great, hasn't it? I've me dejó alucinado todo el asunto. De hecho, estoy
#
# --------------------------------------------------------------------------------
#
# Top-20 predicted tokens:
#
# 1. English text (no steering - baseline):
#    1.  going                                             (prob: 0.1841)
#    2.  just                                              (prob: 0.0792)
#    3.  still                                             (prob: 0.0587)
#    4.  not                                               (prob: 0.0392)
#    5.  a                                                 (prob: 0.0359)
#    6.  so                                                (prob: 0.0348)
#    7.  in                                                (prob: 0.0262)
#    8.  sitting                                           (prob: 0.0207)
#    9.  writing                                           (prob: 0.0183)
#   10.  on                                                (prob: 0.0163)
#   11.  about                                             (prob: 0.0157)
#   12.  gonna                                             (prob: 0.0148)
#   13.  really                                            (prob: 0.0145)
#   14.  here                                              (prob: 0.0143)
#   15.  thinking                                          (prob: 0.0131)
#   16.  having                                            (prob: 0.0126)
#   17.  actually                                          (prob: 0.0124)
#   18.  getting                                           (prob: 0.0122)
#   19.  looking                                           (prob: 0.0097)
#   20.  surprised                                         (prob: 0.0088)
#
# 2. Spanish text (no steering - baseline):
#    1.  muy                                               (prob: 0.1032)
#    2.  en                                                (prob: 0.0648)
#    3.  de                                                (prob: 0.0452)
#    4.  tan                                               (prob: 0.0438)
#    5.  aquí                                              (prob: 0.0294)
#    6.  seguro                                            (prob: 0.0161)
#    7.  pens                                              (prob: 0.0159)
#    8.  a                                                 (prob: 0.0155)
#    9.  un                                                (prob: 0.0122)
#   10.  realmente                                         (prob: 0.0118)
#   11.  bastante                                          (prob: 0.0112)
#   12.  al                                                (prob: 0.0109)
#   13.  con                                               (prob: 0.0107)
#   14.  empez                                             (prob: 0.0106)
#   15.  más                                               (prob: 0.0104)
#   16.  bien                                              (prob: 0.0099)
#   17.  trat                                              (prob: 0.0098)
#   18.  prepar                                            (prob: 0.0098)
#   19.  completamente                                     (prob: 0.0097)
#   20.  list                                              (prob: 0.0080)
#
# 3. Spanish text (WITH steering es->eng):
#    1.  to                                                (prob: 0.0818)
#    2.  very                                              (prob: 0.0724)
#    3.  and                                               (prob: 0.0665)
#    4.  in                                                (prob: 0.0410)
#    5.  on                                                (prob: 0.0215)
#    6.  as                                                (prob: 0.0207)
#    7.  more                                              (prob: 0.0196)
#    8.  even                                              (prob: 0.0195)
#    9.  a                                                 (prob: 0.0194)
#   10.  content                                           (prob: 0.0165)
#   11.  working                                           (prob: 0.0164)
#   12.  at                                                (prob: 0.0163)
#   13.  or                                                (prob: 0.0156)
#   14.  under                                             (prob: 0.0154)
#   15.  all                                               (prob: 0.0135)
#   16.  pretty                                            (prob: 0.0132)
#   17.  here                                              (prob: 0.0131)
#   18.  list                                              (prob: 0.0128)
#   19. ...                                                (prob: 0.0118)
#   20.  out                                               (prob: 0.0117)

# %%
def compute_distribution_metrics(results, verbose=True):
    """
    Compute numerical metrics comparing the three distributions.

    Args:
        results: Dictionary returned by compare_logit_distributions
        verbose: Whether to print the metrics

    Returns:
        Dictionary with various comparison metrics
    """
    # Extract probabilities
    p_eng = results["probs_eng_no_steer"]
    p_es_no = results["probs_es_no_steer"]
    p_es_yes = results["probs_es_with_steer"]

    # KL divergence: D_KL(P || Q) = sum(P * log(P / Q))
    # We add small epsilon to avoid log(0)
    eps = 1e-10

    kl_es_no_to_eng = torch.sum(p_eng * torch.log((p_eng + eps) / (p_es_no + eps))).item()
    kl_es_yes_to_eng = torch.sum(p_eng * torch.log((p_eng + eps) / (p_es_yes + eps))).item()
    kl_es_yes_to_es_no = torch.sum(p_es_no * torch.log((p_es_no + eps) / (p_es_yes + eps))).item()

    # Jensen-Shannon divergence (symmetric version of KL)
    def js_divergence(p, q):
        m = 0.5 * (p + q)
        return (
            0.5 * torch.sum(p * torch.log((p + eps) / (m + eps))).item()
            + 0.5 * torch.sum(q * torch.log((q + eps) / (m + eps))).item()
        )

    js_eng_vs_es_no = js_divergence(p_eng, p_es_no)
    js_eng_vs_es_yes = js_divergence(p_eng, p_es_yes)
    js_es_no_vs_es_yes = js_divergence(p_es_no, p_es_yes)

    # Cosine similarity between probability distributions
    def cosine_sim(p, q):
        return torch.dot(p, q) / (torch.norm(p) * torch.norm(q))

    cos_eng_es_no = cosine_sim(p_eng, p_es_no).item()
    cos_eng_es_yes = cosine_sim(p_eng, p_es_yes).item()
    cos_es_no_es_yes = cosine_sim(p_es_no, p_es_yes).item()

    # Top-k token overlap
    def top_k_overlap(p1, p2, k=50):
        top_k_1 = set(torch.topk(p1, k).indices.cpu().numpy())
        top_k_2 = set(torch.topk(p2, k).indices.cpu().numpy())
        return len(top_k_1 & top_k_2) / k

    overlap_eng_es_no = top_k_overlap(p_eng, p_es_no)
    overlap_eng_es_yes = top_k_overlap(p_eng, p_es_yes)
    overlap_es_no_es_yes = top_k_overlap(p_es_no, p_es_yes)

    metrics = {
        "kl_divergence": {
            "es_no -> eng": kl_es_no_to_eng,
            "es_yes -> eng": kl_es_yes_to_eng,
            "es_yes -> es_no": kl_es_yes_to_es_no,
        },
        "js_divergence": {
            "eng vs es_no": js_eng_vs_es_no,
            "eng vs es_yes": js_eng_vs_es_yes,
            "es_no vs es_yes": js_es_no_vs_es_yes,
        },
        "cosine_similarity": {
            "eng vs es_no": cos_eng_es_no,
            "eng vs es_yes": cos_eng_es_yes,
            "es_no vs es_yes": cos_es_no_es_yes,
        },
        "top50_overlap": {
            "eng vs es_no": overlap_eng_es_no,
            "eng vs es_yes": overlap_eng_es_yes,
            "es_no vs es_yes": overlap_es_no_es_yes,
        },
    }

    if verbose:
        print("\n" + "=" * 80)
        print("NUMERICAL COMPARISON METRICS")
        print("=" * 80)

        print("\nKL Divergence (lower = more similar):")
        print(f"  es (no steer) → Eng:        {metrics['kl_divergence']['es_no -> eng']:.4f}")
        print(f"  es (WITH steer) → Eng:      {metrics['kl_divergence']['es_yes -> eng']:.4f}")

        print("\nJensen-Shannon Divergence (lower = more similar, symmetric):")
        print(f"  Eng vs es (no steer):       {metrics['js_divergence']['eng vs es_no']:.4f}")
        print(f"  Eng vs es (WITH steer):     {metrics['js_divergence']['eng vs es_yes']:.4f}")

        print("\nCosine Similarity (higher = more similar, range [-1, 1]):")
        print(f"  Eng vs es (no steer):       {metrics['cosine_similarity']['eng vs es_no']:.4f}")
        print(f"  Eng vs es (WITH steer):     {metrics['cosine_similarity']['eng vs es_yes']:.4f}")

        print("\nTop-50 Token Overlap (higher = more similar, range [0, 1]):")
        print(f"  Eng vs es (no steer):       {metrics['top50_overlap']['eng vs es_no']:.2%}")
        print(f"  Eng vs es (WITH steer):     {metrics['top50_overlap']['eng vs es_yes']:.2%}")

    return metrics


# Compute metrics for the previous results
metrics = compute_distribution_metrics(results)
# Out:
# ================================================================================
# NUMERICAL COMPARISON METRICS
# ================================================================================
#
# KL Divergence (lower = more similar):
#   es (no steer) → Eng:        6.9936
#   es (WITH steer) → Eng:      2.6597
#
# Jensen-Shannon Divergence (lower = more similar, symmetric):
#   Eng vs es (no steer):       0.6452
#   Eng vs es (WITH steer):     0.4264
#
# Cosine Similarity (higher = more similar, range [-1, 1]):
#   Eng vs es (no steer):       0.0197
#   Eng vs es (WITH steer):     0.1502
#
# Top-50 Token Overlap (higher = more similar, range [0, 1]):
#   Eng vs es (no steer):       2.00%
#   Eng vs es (WITH steer):     28.00%

# %%
import matplotlib.pyplot as plt


def visualize_logit_distributions(results, top_k=20):
    """
    Create visualizations comparing the three logit distributions.

    Args:
        results: Dictionary returned by compare_logit_distributions
        top_k: Number of top tokens to visualize
    """
    # Extract probabilities
    p_eng = results["probs_eng_no_steer"]
    p_es_no = results["probs_es_no_steer"]
    p_es_yes = results["probs_es_with_steer"]

    # Get top-k indices from each distribution
    top_k_eng_indices = torch.topk(p_eng, top_k).indices
    top_k_es_no_indices = torch.topk(p_es_no, top_k).indices
    top_k_es_yes_indices = torch.topk(p_es_yes, top_k).indices

    # Combine all unique indices
    all_indices = torch.unique(torch.cat([top_k_eng_indices, top_k_es_no_indices, top_k_es_yes_indices]))

    # Get probabilities for these indices
    p_eng_subset = p_eng[all_indices].cpu().numpy()
    p_es_no_subset = p_es_no[all_indices].cpu().numpy()
    p_es_yes_subset = p_es_yes[all_indices].cpu().numpy()

    # Get token strings
    tokens = [tokenizer.decode([idx]) for idx in all_indices]

    # Create figure with single plot
    fig = plt.figure(figsize=(14, 6))

    # Bar chart comparing probabilities for top tokens
    x = np.arange(len(tokens))
    width = 0.25

    plt.bar(x - width, p_eng_subset, width, label="Eng (no steer)", alpha=0.8)
    plt.bar(x, p_es_no_subset, width, label="es (no steer)", alpha=0.8)
    plt.bar(x + width, p_es_yes_subset, width, label="es (WITH steer)", alpha=0.8)

    plt.xlabel("Token")
    plt.ylabel("Probability")
    plt.title("Probability Distribution Comparison (Union of Top-K Tokens)")
    # plt.xticks(x, tokens, rotation=45, ha="right")
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

    return fig


# Create visualizations
fig = visualize_logit_distributions(results, top_k=20)
# Out:
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from tqdm import tqdm


def run_experiment_on_dataset(max_samples=None, steering_value=-3.0):
    """
    Run the logit comparison experiment on the entire dataset.

    Args:
        max_samples: Maximum number of samples to process (None for all)
        steering_value: Steering direction value to apply (default: -3.0)

    Returns:
        DataFrame with aggregated results
    """
    all_metrics = []

    num_samples = len(df_en_ru) if max_samples is None else min(max_samples, len(df_en_ru))

    print(f"Running experiment on {num_samples} samples...")

    for idx in tqdm(range(num_samples)):
        # Get results for this sample (suppress output)
        results = compare_logit_distributions(sample_idx=idx, top_k=500, verbose=False, steering_value=steering_value)

        # Compute metrics (suppress output)
        sample_metrics = compute_distribution_metrics(results, verbose=False)

        # Add sample index
        sample_metrics["sample_idx"] = idx

        # Flatten the nested dictionary
        flattened = {
            "sample_idx": idx,
            "kl_es_no_to_eng": sample_metrics["kl_divergence"]["es_no -> eng"],
            "kl_es_yes_to_eng": sample_metrics["kl_divergence"]["es_yes -> eng"],
            "kl_es_yes_to_es_no": sample_metrics["kl_divergence"]["es_yes -> es_no"],
            "js_eng_vs_es_no": sample_metrics["js_divergence"]["eng vs es_no"],
            "js_eng_vs_es_yes": sample_metrics["js_divergence"]["eng vs es_yes"],
            "js_es_no_vs_es_yes": sample_metrics["js_divergence"]["es_no vs es_yes"],
            "cos_eng_vs_es_no": sample_metrics["cosine_similarity"]["eng vs es_no"],
            "cos_eng_vs_es_yes": sample_metrics["cosine_similarity"]["eng vs es_yes"],
            "cos_es_no_vs_es_yes": sample_metrics["cosine_similarity"]["es_no vs es_yes"],
            "overlap_eng_vs_es_no": sample_metrics["top50_overlap"]["eng vs es_no"],
            "overlap_eng_vs_es_yes": sample_metrics["top50_overlap"]["eng vs es_yes"],
            "overlap_es_no_vs_es_yes": sample_metrics["top50_overlap"]["es_no vs es_yes"],
        }

        all_metrics.append(flattened)

    # Convert to DataFrame
    results_df = pd.DataFrame(all_metrics)

    return results_df

# %%
def grid_search_steering_direction(steering_values, num_samples=100):
    """
    Perform grid search over steering direction values.

    Args:
        steering_values: List of steering direction values to test
        num_samples: Number of samples to test for each steering value

    Returns:
        DataFrame with results for each steering value
    """
    all_results = []

    print(f"Grid search over {len(steering_values)} steering values, {num_samples} samples each...")

    for steering_val in tqdm(steering_values, desc="Steering values"):
        sample_metrics = []

        for idx in range(min(num_samples, len(df_en_ru))):
            # Get results for this sample using the parameterized function
            results = compare_logit_distributions(sample_idx=idx, top_k=500, verbose=False, steering_value=steering_val)

            # Compute metrics
            metrics = compute_distribution_metrics(results, verbose=False)

            sample_metrics.append(
                {
                    "kl_divergence": metrics["kl_divergence"]["es_yes -> eng"],
                    "js_divergence": metrics["js_divergence"]["eng vs es_yes"],
                    "cosine_similarity": metrics["cosine_similarity"]["eng vs es_yes"],
                    "top50_overlap": metrics["top50_overlap"]["eng vs es_yes"],
                }
            )

        # Aggregate metrics across samples
        avg_kl = np.mean([m["kl_divergence"] for m in sample_metrics])
        avg_js = np.mean([m["js_divergence"] for m in sample_metrics])
        avg_cos = np.mean([m["cosine_similarity"] for m in sample_metrics])
        avg_overlap = np.mean([m["top50_overlap"] for m in sample_metrics])

        std_kl = np.std([m["kl_divergence"] for m in sample_metrics])
        std_js = np.std([m["js_divergence"] for m in sample_metrics])
        std_cos = np.std([m["cosine_similarity"] for m in sample_metrics])
        std_overlap = np.std([m["top50_overlap"] for m in sample_metrics])

        all_results.append(
            {
                "steering_value": steering_val,
                "avg_kl_divergence": avg_kl,
                "avg_js_divergence": avg_js,
                "avg_cosine_similarity": avg_cos,
                "avg_top50_overlap": avg_overlap,
                "std_kl_divergence": std_kl,
                "std_js_divergence": std_js,
                "std_cosine_similarity": std_cos,
                "std_top50_overlap": std_overlap,
            }
        )

    return pd.DataFrame(all_results)


# Define steering values to test
steering_values = np.arange(-1.0, -5.1, -0.1)

# Run grid search
grid_results = grid_search_steering_direction(steering_values, num_samples=100)
# Out:
# Grid search over 41 steering values, 100 samples each...
# Steering values: 100%|██████████| 41/41 [13:35<00:00, 19.90s/it]

# %%
# Display grid search results
print("\n" + "=" * 80)
print("GRID SEARCH RESULTS")
print("=" * 80)
print(grid_results.to_string(index=False))

# Find optimal values for each metric
print("\n" + "=" * 80)
print("OPTIMAL STEERING VALUES")
print("=" * 80)

# For KL and JS: lower is better
best_kl_idx = grid_results["avg_kl_divergence"].idxmin()
print("\nBest for KL Divergence:")
print(f"  Steering value: {grid_results.loc[best_kl_idx, 'steering_value']:.2f}")
print(
    f"  KL Divergence:  {grid_results.loc[best_kl_idx, 'avg_kl_divergence']:.4f} ± {grid_results.loc[best_kl_idx, 'std_kl_divergence']:.4f}"
)

best_js_idx = grid_results["avg_js_divergence"].idxmin()
print("\nBest for JS Divergence:")
print(f"  Steering value: {grid_results.loc[best_js_idx, 'steering_value']:.2f}")
print(
    f"  JS Divergence:  {grid_results.loc[best_js_idx, 'avg_js_divergence']:.4f} ± {grid_results.loc[best_js_idx, 'std_js_divergence']:.4f}"
)

# For cosine similarity and overlap: higher is better
best_cos_idx = grid_results["avg_cosine_similarity"].idxmax()
print("\nBest for Cosine Similarity:")
print(f"  Steering value:      {grid_results.loc[best_cos_idx, 'steering_value']:.2f}")
print(
    f"  Cosine Similarity:   {grid_results.loc[best_cos_idx, 'avg_cosine_similarity']:.4f} ± {grid_results.loc[best_cos_idx, 'std_cosine_similarity']:.4f}"
)

best_overlap_idx = grid_results["avg_top50_overlap"].idxmax()
print("\nBest for Top-50 Overlap:")
print(f"  Steering value:  {grid_results.loc[best_overlap_idx, 'steering_value']:.2f}")
print(
    f"  Top-50 Overlap:  {grid_results.loc[best_overlap_idx, 'avg_top50_overlap']:.2%} ± {grid_results.loc[best_overlap_idx, 'std_top50_overlap']:.2%}"
)
# Out:
# ================================================================================
# GRID SEARCH RESULTS
# ================================================================================
#  steering_value  avg_kl_divergence  avg_js_divergence  avg_cosine_similarity  avg_top50_overlap  std_kl_divergence  std_js_divergence  std_cosine_similarity  std_top50_overlap
#            -1.0           4.924098           0.529824               0.163678             0.1576           2.414222           0.142005               0.237951           0.150766
#            -1.1           4.800424           0.523947               0.169816             0.1668           2.408347           0.141754               0.238561           0.150286
#            -1.2           4.683334           0.518066               0.175900             0.1760           2.403773           0.141550               0.239268           0.152184
#            -1.3           4.572716           0.512208               0.181950             0.1848           2.400098           0.141407               0.240018           0.153026
#            -1.4           4.468414           0.506401               0.188003             0.1940           2.396960           0.141329               0.240786           0.155293
#            -1.5           4.370245           0.500673               0.194096             0.2042           2.394043           0.141318               0.241578           0.156341
#            -1.6           4.278009           0.495054               0.200250             0.2148           2.391076           0.141374               0.242418           0.157648
#            -1.7           4.191488           0.489571               0.206476             0.2220           2.387835           0.141489               0.243333           0.159587
#            -1.8           4.110474           0.484253               0.212766             0.2288           2.384144           0.141653               0.244347           0.161773
#            -1.9           4.034760           0.479126               0.219088             0.2374           2.379868           0.141855               0.245475           0.161484
#            -2.0           3.964152           0.474214               0.225367             0.2452           2.374912           0.142078               0.246716           0.164113
#            -2.1           3.898462           0.469540               0.231489             0.2526           2.369220           0.142307               0.248040           0.163918
#            -2.2           3.837519           0.465124               0.237312             0.2590           2.362761           0.142526               0.249371           0.166262
#            -2.3           3.781158           0.460982               0.242701             0.2646           2.355545           0.142720               0.250611           0.167734
#            -2.4           3.729220           0.457126               0.247563             0.2700           2.347600           0.142876               0.251673           0.169670
#            -2.5           3.681554           0.453568               0.251861             0.2768           2.338979           0.142986               0.252508           0.170616
#            -2.6           3.638012           0.450312               0.255609             0.2814           2.329756           0.143040               0.253115           0.171797
#            -2.7           3.598451           0.447363               0.258857             0.2858           2.320015           0.143036               0.253534           0.172495
#            -2.8           3.562732           0.444719               0.261674             0.2880           2.309851           0.142970               0.253822           0.172139
#            -2.9           3.530718           0.442380               0.264124             0.2918           2.299363           0.142843               0.254042           0.171653
#            -3.0           3.502274           0.440341               0.266263             0.2950           2.288650           0.142654               0.254245           0.172960
#            -3.1           3.477268           0.438597               0.268128             0.2962           2.277806           0.142407               0.254465           0.172016
#            -3.2           3.455568           0.437138               0.269741             0.2980           2.266925           0.142104               0.254725           0.171732
#            -3.3           3.437041           0.435958               0.271111             0.3012           2.256088           0.141747               0.255029           0.171856
#            -3.4           3.421556           0.435045               0.272237             0.3016           2.245369           0.141341               0.255375           0.171667
#            -3.5           3.408980           0.434390               0.273115             0.3010           2.234834           0.140888               0.255755           0.170232
#            -3.6           3.399182           0.433981               0.273741             0.3022           2.224537           0.140390               0.256155           0.170197
#            -3.7           3.392029           0.433806               0.274115             0.3030           2.214523           0.139851               0.256564           0.170584
#            -3.8           3.387391           0.433853               0.274240             0.3010           2.204822           0.139272               0.256968           0.169337
#            -3.9           3.385140           0.434111               0.274123             0.3012           2.195463           0.138655               0.257358           0.168043
#            -4.0           3.385146           0.434568               0.273777             0.3000           2.186455           0.138001               0.257721           0.166253
#            -4.1           3.387287           0.435212               0.273215             0.3004           2.177808           0.137310               0.258048           0.164754
#            -4.2           3.391440           0.436030               0.272453             0.2984           2.169519           0.136585               0.258327           0.165377
#            -4.3           3.397485           0.437012               0.271506             0.2958           2.161579           0.135826               0.258547           0.164762
#            -4.4           3.405306           0.438147               0.270387             0.2938           2.153977           0.135035               0.258699           0.163773
#            -4.5           3.414792           0.439422               0.269105             0.2908           2.146695           0.134214               0.258772           0.161627
#            -4.6           3.425833           0.440828               0.267670             0.2888           2.139714           0.133365               0.258754           0.161228
#            -4.7           3.438323           0.442354               0.266086             0.2870           2.133014           0.132491               0.258634           0.160334
#            -4.8           3.452160           0.443989               0.264357             0.2852           2.126568           0.131596               0.258396           0.161310
#            -4.9           3.467246           0.445722               0.262483             0.2830           2.120357           0.130683               0.258025           0.159884
#            -5.0           3.483483           0.447544               0.260465             0.2810           2.114357           0.129756               0.257507           0.159884
#
# ================================================================================
# OPTIMAL STEERING VALUES
# ================================================================================
#
# Best for KL Divergence:
#   Steering value: -3.90
#   KL Divergence:  3.3851 ± 2.1955
#
# Best for JS Divergence:
#   Steering value: -3.70
#   JS Divergence:  0.4338 ± 0.1399
#
# Best for Cosine Similarity:
#   Steering value:      -3.80
#   Cosine Similarity:   0.2742 ± 0.2570
#
# Best for Top-50 Overlap:
#   Steering value:  -3.70
#   Top-50 Overlap:  30.30% ± 17.06%

# %%
# Visualize grid search results
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# 1. KL Divergence vs Steering Value
ax1 = axes[0, 0]
ax1.plot(grid_results["steering_value"], grid_results["avg_kl_divergence"], "o-", linewidth=2, markersize=4)
best_kl_idx = grid_results["avg_kl_divergence"].idxmin()
ax1.set_xlabel("Steering Strength")
ax1.set_ylabel("KL Divergence")
ax1.legend()
ax1.grid(True, alpha=0.3)

# 2. JS Divergence vs Steering Value
ax2 = axes[0, 1]
ax2.plot(
    grid_results["steering_value"], grid_results["avg_js_divergence"], "o-", linewidth=2, markersize=4, color="orange"
)
best_js_idx = grid_results["avg_js_divergence"].idxmin()
ax2.set_xlabel("Steering Strength")
ax2.set_ylabel("JS Divergence")
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3602/1016147364.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# /tmp/ipykernel_3602/1016147364.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend()
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np

# Run on entire dataset (or subset for testing)
# Use max_samples=100 for quick testing, None for full dataset
results_df = run_experiment_on_dataset(
    max_samples=None,
    steering_value=grid_results.loc[best_js_idx, "steering_value"],
)
# Out:
# Running experiment on 2467 samples...
#   0%|          | 0/2467 [00:00<?, ?it/s]
# 100%|██████████| 2467/2467 [05:48<00:00,  7.08it/s]

# %%
# Display summary statistics
print("\n" + "=" * 80)
print("AGGREGATED RESULTS ACROSS ALL SAMPLES")
print("=" * 80)

print("\n" + "-" * 80)
print("KL DIVERGENCE (lower = more similar)")
print("-" * 80)
print("\nes (no steer) → Eng:")
print(f"  Mean: {results_df['kl_es_no_to_eng'].mean():.4f}")
print(f"  Std:  {results_df['kl_es_no_to_eng'].std():.4f}")
print(f"  Med:  {results_df['kl_es_no_to_eng'].median():.4f}")

print("\nes (WITH steer) → Eng:")
print(f"  Mean: {results_df['kl_es_yes_to_eng'].mean():.4f}")
print(f"  Std:  {results_df['kl_es_yes_to_eng'].std():.4f}")
print(f"  Med:  {results_df['kl_es_yes_to_eng'].median():.4f}")

print(
    f"\n💡 Improvement: {((results_df['kl_es_no_to_eng'].mean() - results_df['kl_es_yes_to_eng'].mean()) / results_df['kl_es_no_to_eng'].mean() * 100):.1f}% reduction in KL divergence"
)

print("\n" + "-" * 80)
print("JENSEN-SHANNON DIVERGENCE (lower = more similar, symmetric)")
print("-" * 80)
print("\nEng vs es (no steer):")
print(f"  Mean: {results_df['js_eng_vs_es_no'].mean():.4f}")
print(f"  Std:  {results_df['js_eng_vs_es_no'].std():.4f}")
print(f"  Med:  {results_df['js_eng_vs_es_no'].median():.4f}")

print("\nEng vs es (WITH steer):")
print(f"  Mean: {results_df['js_eng_vs_es_yes'].mean():.4f}")
print(f"  Std:  {results_df['js_eng_vs_es_yes'].std():.4f}")
print(f"  Med:  {results_df['js_eng_vs_es_yes'].median():.4f}")

print(
    f"\n💡 Improvement: {((results_df['js_eng_vs_es_no'].mean() - results_df['js_eng_vs_es_yes'].mean()) / results_df['js_eng_vs_es_no'].mean() * 100):.1f}% reduction in JS divergence"
)

print("\n" + "-" * 80)
print("COSINE SIMILARITY (higher = more similar, range [-1, 1])")
print("-" * 80)
print("\nEng vs es (no steer):")
print(f"  Mean: {results_df['cos_eng_vs_es_no'].mean():.4f}")
print(f"  Std:  {results_df['cos_eng_vs_es_no'].std():.4f}")
print(f"  Med:  {results_df['cos_eng_vs_es_no'].median():.4f}")

print("\nEng vs es (WITH steer):")
print(f"  Mean: {results_df['cos_eng_vs_es_yes'].mean():.4f}")
print(f"  Std:  {results_df['cos_eng_vs_es_yes'].std():.4f}")
print(f"  Med:  {results_df['cos_eng_vs_es_yes'].median():.4f}")

print(
    f"\n💡 Improvement: {((results_df['cos_eng_vs_es_yes'].mean() - results_df['cos_eng_vs_es_no'].mean()) / (1 - results_df['cos_eng_vs_es_no'].mean()) * 100):.1f}% increase toward perfect similarity"
)

print("\n" + "-" * 80)
print("TOP-50 TOKEN OVERLAP (higher = more similar, range [0, 1])")
print("-" * 80)
print("\nEng vs es (no steer):")
print(f"  Mean: {results_df['overlap_eng_vs_es_no'].mean():.2%}")
print(f"  Std:  {results_df['overlap_eng_vs_es_no'].std():.2%}")
print(f"  Med:  {results_df['overlap_eng_vs_es_no'].median():.2%}")

print("\nEng vs es (WITH steer):")
print(f"  Mean: {results_df['overlap_eng_vs_es_yes'].mean():.2%}")
print(f"  Std:  {results_df['overlap_eng_vs_es_yes'].std():.2%}")
print(f"  Med:  {results_df['overlap_eng_vs_es_yes'].median():.2%}")

print(
    f"\n💡 Improvement: {((results_df['overlap_eng_vs_es_yes'].mean() - results_df['overlap_eng_vs_es_no'].mean()) / (1 - results_df['overlap_eng_vs_es_no'].mean()) * 100):.1f}% increase toward perfect overlap"
)
# Out:
# ================================================================================
# AGGREGATED RESULTS ACROSS ALL SAMPLES
# ================================================================================
#
# --------------------------------------------------------------------------------
# KL DIVERGENCE (lower = more similar)
# --------------------------------------------------------------------------------
#
# es (no steer) → Eng:
#   Mean: 6.5210
#   Std:  2.9227
#   Med:  6.6270
#
# es (WITH steer) → Eng:
#   Mean: 3.4755
#   Std:  2.3306
#   Med:  2.9615
#
# 💡 Improvement: 46.7% reduction in KL divergence
#
# --------------------------------------------------------------------------------
# JENSEN-SHANNON DIVERGENCE (lower = more similar, symmetric)
# --------------------------------------------------------------------------------
#
# Eng vs es (no steer):
#   Mean: 0.5845
#   Std:  0.1478
#   Med:  0.6420
#
# Eng vs es (WITH steer):
#   Mean: 0.4403
#   Std:  0.1549
#   Med:  0.4525
#
# 💡 Improvement: 24.7% reduction in JS divergence
#
# --------------------------------------------------------------------------------
# COSINE SIMILARITY (higher = more similar, range [-1, 1])
# --------------------------------------------------------------------------------
#
# Eng vs es (no steer):
#   Mean: 0.1192
#   Std:  0.2543
#   Med:  0.0088
#
# Eng vs es (WITH steer):
#   Mean: 0.2920
#   Std:  0.2965
#   Med:  0.1825
#
# 💡 Improvement: 19.6% increase toward perfect similarity
#
# --------------------------------------------------------------------------------
# TOP-50 TOKEN OVERLAP (higher = more similar, range [0, 1])
# --------------------------------------------------------------------------------
#
# Eng vs es (no steer):
#   Mean: 11.45%
#   Std:  14.74%
#   Med:  6.00%
#
# Eng vs es (WITH steer):
#   Mean: 30.74%
#   Std:  16.24%
#   Med:  30.00%
#
# 💡 Improvement: 21.8% increase toward perfect overlap
